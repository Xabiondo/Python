# %%
#Enlace a la información
#https://www.kaggle.com/code/residentmario/indexing-selecting-assigning

# %%
import pandas as pd

# %%
titanic_pasajeros = pd.read_csv("C:/Users/xabie/Desktop/gitProyectos/Python/datasets/Titanic-Dataset.csv" )

# %%
titanic_pasajeros.head()

# %%
titanic_pasajeros.Survived

# %%
titanic_pasajeros['Survived']

# %%
titanic_pasajeros["Name"][0]

# %%
titanic_pasajeros.iloc[0]
#Iloc engancha la fila entera, con el índice de parámetro

# %%
titanic_pasajeros.iloc[0 , 4] #fila primero, columa segundo

# %%
#Para coger toda una columa, o fila se haría así
titanic_pasajeros.iloc[: , 1] #Así se sacan todos los datos de una columa
titanic_pasajeros.iloc[1 , :] #asi todos los datos de una fila

# %%
titanic_pasajeros.iloc[:3 , :] #Esto es básicamente, todo hasta el 3
#De hacerlo al revés sería, todo menos los tres primeros .

# %%
titanic_pasajeros.iloc[1:3 , 0 ] #ESto quiere decir del índice 1 (segunda fila , hasta la tercera, pero sólo el id (primera columna))

# %%
titanic_pasajeros.iloc[[0 , 1 ,2 ,3 ] , 3] #Todos  los nombres de los 4 primeros

# %%
titanic_pasajeros.iloc[-5 : ] #Los últimos 5
#si esta a la izquierda del los dos puntos, es

# %%
#Acceso a datos usando el índice String
titanic_pasajeros.loc[0 , 'Name']

# %%
titanic_pasajeros.loc[: , ['Name' , 'Survived']]
#TODAS LAS FILAS, QUE TENGAN ESOS CAMPOS DE COLUMNA

# %%
titanic_pasajeros.set_index("Name")
#Para usar de índice una etiqueta (nombres de las columnas)

# %%
titanic_pasajeros.set_index("Pclass")

# %%
titanic_pasajeros['Name'] == 'male'

# %%
titanic_pasajeros.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_pasajeros.loc[(titanic_pasajeros['Sex'] == 'male') & (titanic_pasajeros['Survived']) & (titanic_pasajeros['Fare'] > 20)]

# %%
titanic_pasajeros.loc[(titanic_pasajeros['Fare'] > 2550 ) | (titanic_pasajeros['Sex'] == 'female')]

# %%
titanic_pasajeros.loc[titanic_pasajeros['Cabin'].isin(['C123' , 'C85'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 137          138         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 137                        Futrelle, Mr. Jacques Heath    male  37.0      1
#
#      Parch    Ticket     Fare Cabin Embarked
# 1        0  PC 17599  71.2833   C85        C
# 3        0    113803  53.1000  C123        S
# 137      0    113803  53.1000  C123        S

# %%
titanic_pasajeros.loc[titanic_pasajeros['Cabin'].notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_pasajeros['Name'] = 'pasajero'

# %%
titanic_pasajeros.head()
# Out:
#    PassengerId  Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# 0            1         0       3  pasajero1    male  22.0      1      0
# 1            2         1       1  pasajero1  female  38.0      1      0
# 2            3         1       3  pasajero1  female  26.0      0      0
# 3            4         1       1  pasajero1  female  35.0      1      0
# 4            5         0       3  pasajero1    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
titanic_pasajeros['PassengerId'] = range(len(titanic_pasajeros) , 0 , -1)

# %%
titanic_pasajeros.head()
# Out:
#    PassengerId  Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# 0          891         0       3  pasajero1    male  22.0      1      0
# 1          890         1       1  pasajero1  female  38.0      1      0
# 2          889         1       3  pasajero1  female  26.0      0      0
# 3          888         1       1  pasajero1  female  35.0      1      0
# 4          887         0       3  pasajero1    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
