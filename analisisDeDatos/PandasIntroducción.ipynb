# %%
import pandas as pd

# %%
pd.DataFrame({'Duros' : [ 'Xabi' , 'Javi'] , 'Blandos'
              : ['Wasoski' , 7] })

# %%
pd.DataFrame({'Programadores' : ['Xabi' , 'Javi'] , 'Ricos' : ['1' , '1']}
             , index= ['Nombres' , 'CApacidad adquisitiva'] )

# %%
pd.Series([1 , 2 ,3 ,4 ,5])
#Es básicamente , una lista normal y corriente, con sus índices empezando desde el 0

# %%
pd.Series([120 , 120 ,700] , index= ['VEntas enero' , 'Ventas febrero' , 'Ventas marzo'])

# %%
titanic_pasajeros = pd.read_csv("C:/Users/xabie/Desktop/gitProyectos/Python/datasets/Titanic-Dataset.csv")

# %%
titanic_pasajeros.shape
# Out:
# (891, 12)

# %%
titanic_pasajeros.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
titanic_pasajeros = pd.read_csv("C:/Users/xabie/Desktop/gitProyectos/Python/datasets/Titanic-Dataset.csv" , index_col = 1)
titanic_pasajeros.head()
#Esto evidentemente , no tiene ninggun sentido, era por trastear.
# Out:
#           PassengerId  Pclass  \
# Survived
# 0                   1       3
# 1                   2       1
# 1                   3       3
# 1                   4       1
# 0                   5       3
#
#                                                        Name     Sex   Age  \
# Survived
# 0                                   Braund, Mr. Owen Harris    male  22.0
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 1                                    Heikkinen, Miss. Laina  female  26.0
# 1              Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 0                                  Allen, Mr. William Henry    male  35.0
#
#           SibSp  Parch            Ticket     Fare Cabin Embarked
# Survived
# 0             1      0         A/5 21171   7.2500   NaN        S
# 1             1      0          PC 17599  71.2833   C85        C
# 1             0      0  STON/O2. 3101282   7.9250   NaN        S
# ...
